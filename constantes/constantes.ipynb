# %%
#a. Path BBDD input.
path_db = "./inputs/data.db"
#b. Paths train y test.
path_a_predecir = "./inputs/ejemplo.csv"
path_train_crudo = "./inputs/train_crudo.csv"
path_test_crudo = "./inputs/test_crudo.csv"
path_train_fe = "./inputs/train_fe.csv"
path_test_fe = "./inputs/test_fe.csv"
path_libros_fe = "./inputs/libros_fe.csv"
path_lectores_fe = "./inputs/lectores_fe.csv"
#c. Modo de ejecución: "validacion" entrena solo con train (permite medir nDCG),
# "entrega" entrena con train+test (usa todo el historial disponible para predecir).
MODO = "validacion"
#d. Path modelo entrenado.
path_modelo = "modelo_recomendador.pkl"
#e. Año de referencia como cierre.
anio_actual = 2024
#f. Mapeo para agrupar generos de libros.
map_genero = {
    "narrativa": ["narrativa", "novela"],
    "terror": ["novela negra, intriga, terror", "novela negra"],
    "ensayo": ["ensayo"],
    "juvenil": ["infantil y juvenil", "juvenil"],
    "historica_aventuras": ["historica y aventuras", "historia militar"],
    "romantica_erotica": ["romantica, erotica"],
    "ciencia_ficcion_fantastica": ["fantastica, ciencia ficcion"],
    "ficcion_literaria": ["ficcion literaria"],
    "literatura_contemporanea": ["literatura contemporanea"],
    "comics": ["comics, novela grafica"],
    "biografias": ["biografias, memorias"],
    "lecturas_complementarias": ["lecturas complementarias"],
    "poesia_teatro": ["poesia, teatro", "poesia"],
    "no_ficcion": ["no ficcion"],
    "clasicos": ["clasicos de la literatura"],
    "humor": ["humor"],
    "historia": ["historia", "historia del cine"],
    "autoayuda_espiritualidad": ["autoayuda y espiritualidad", "esoterismo y ocultismo"],
    "arte_musica": ["musica", "arte", "fotografia"],
    "audiovisual": ["television", "peliculas"],
    "economia_empresa": ["economia", "empresa", "economia, empresa, marketing", "marketing y publicidad"],
    "ciencia_naturaleza": ["naturaleza y ciencia"],
    "salud_medicina": ["medicina", "medicina divulgativa", "dietetica y nutricion"],
    "viajes": ["guias de viaje", "viajes en bolsillo"],
    "pedagogia": ["psicologia y pedagogia", "didactica y metodologia", "filologia"],
    "idiomas": ["idiomas"],
    "sociedad_filosofia": ["filosofia contemporanea", "feminismo y mujer", "derecho"],
    "deportes_juegos": ["deportes y juegos"],
    "cocina": ["cocina"],
    "informatica": ["informatica"],
    "varios": ["varios", "varios, otros generos"],
    "sin_dato": [""],
}
